# %% [markdown]
# # Coderscave Phase 1 Terrorism

# %%
import math
import warnings
import numpy as np 
import pandas as pd 
import seaborn as sns
import plotly.offline as py
import plotly.graph_objs as go
import matplotlib.pyplot as plt

# %%
import pandas as pd

# Specify the file path
file_path = r"C:\Users\KARTHIK\Downloads\Terrorism.csv"

# Try reading the CSV file with different encoding options
try:
    df = pd.read_csv(file_path, encoding='utf-8')
except UnicodeDecodeError:
    # If utf-8 encoding fails, try another encoding
    df = pd.read_csv(file_path, encoding='latin1')

# Display the first few rows of the DataFrame to verify the import
print(df.head())
# Out:
# C:\Users\KARTHIK\AppData\Local\Temp\ipykernel_7280\3656555517.py:11: DtypeWarning:
#
# Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# ...

# %%
# Display the column names
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
# Change the column names
df.rename(columns = {'iyear':'Year','imonth':'Month','iday':'Day','country_txt':'Country','provstate':'state',
                       'region_txt':'Region','attacktype1_txt':'AttackType','target1':'Target','nkill':'Killed',
                       'nwound':'Wounded','summary':'Summary','gname':'Group','targtype1_txt':'Target_type',
                       'weaptype1_txt':'Weapon_type','motive':'Motive'}, inplace=True)
print("Column names have been changed successfully")
# Out:
# Column names have been changed successfully

# %%
# Displays the information of dataset 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
# Displays the count, mean, max, min of values from each columns
df.describe()
# Out:
#             eventid           Year          Month            Day  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
# Displays the number of rows and columns of the dataset
df.shape
# Out:
# (181691, 135)

# %%
# Drop the Eventid column
df.drop(columns=['eventid'], inplace=True)

# %%
df.head()
# Out:
#    Year  Month  Day approxdate  extended resolution  country  \
# 0  1970      7    2        NaN         0        NaN       58
# 1  1970      0    0        NaN         0        NaN      130
# 2  1970      1    0        NaN         0        NaN      160
# 3  1970      1    0        NaN         0        NaN       78
# 4  1970      1    0        NaN         0        NaN      101
#
#               Country  region                       Region  ... addnotes  \
# 0  Dominican Republic       2  Central America & Caribbean  ...      NaN
# 1              Mexico       1                North America  ...      NaN
# 2         Philippines       5               Southeast Asia  ...      NaN
# 3              Greece       8               Western Europe  ...      NaN
# 4               Japan       4                    East Asia  ...      NaN
#
#   scite1  scite2  scite3  dbsource  INT_LOG INT_IDEO INT_MISC  INT_ANY  \
# 0    NaN     NaN     NaN      PGIS        0        0        0        0
# ...

# %%
#Check for the null values
df.isnull().sum()
# Out:
# Year               0
# Month              0
# Day                0
# approxdate    172452
# extended           0
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 134, dtype: int64

# %%
# Check for the unique values in some of the columns
df.loc[:,'Year'].unique()
# Out:
# array([1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980,
#        1981, 1986, 1982, 1983, 1984, 1985, 1987, 1988, 1989, 1990, 1991,
#        1992, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003,
#        2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014,
#        2015, 2016, 2017], dtype=int64)

# %%
# Assuming df is your DataFrame
country_list = df.loc[:, 'Country'].unique()
print(country_list)
# Out:
# ['Dominican Republic' 'Mexico' 'Philippines' 'Greece' 'Japan'
#  'United States' 'Uruguay' 'Italy' 'East Germany (GDR)' 'Ethiopia'
#  'Guatemala' 'Venezuela' 'West Germany (FRG)' 'Switzerland' 'Jordan'
#  'Spain' 'Brazil' 'Egypt' 'Argentina' 'Lebanon' 'Ireland' 'Turkey'
#  'Paraguay' 'Iran' 'United Kingdom' 'Colombia' 'Bolivia' 'Nicaragua'
#  'Netherlands' 'Belgium' 'Canada' 'Australia' 'Pakistan' 'Zambia' 'Sweden'
#  'Costa Rica' 'South Yemen' 'Cambodia' 'Israel' 'Poland' 'Taiwan' 'Panama'
#  'Kuwait' 'West Bank and Gaza Strip' 'Austria' 'Czechoslovakia' 'India'
#  'France' 'South Vietnam' 'Brunei' 'Zaire'
#  "People's Republic of the Congo" 'Portugal' 'Algeria' 'El Salvador'
#  'Thailand' 'Haiti' 'Sudan' 'Morocco' 'Cyprus' 'Myanmar' 'Afghanistan'
#  'Peru' 'Chile' 'Honduras' 'Yugoslavia' 'Ecuador' 'New Zealand' 'Malaysia'
#  'Singapore' 'Botswana' 'Jamaica' 'Chad' 'North Yemen' 'Andorra' 'Syria'
#  'South Korea' 'United Arab Emirates' 'South Africa' 'Kenya' 'Iraq'
# ...

# %%
# Total count of the country in the dataset
pd.DataFrame(df.Country).count()
# Out:
# Country    181691
# dtype: int64

# %%
# Fill the null values with "Not_Known"
df = df.fillna('Not_Known')

# %%
# Check for the null values in the dataset should be empty by now
df.isnull().sum()
# Out:
# Year          0
# Month         0
# Day           0
# approxdate    0
# extended      0
#              ..
# INT_LOG       0
# INT_IDEO      0
# INT_MISC      0
# INT_ANY       0
# related       0
# Length: 134, dtype: int64

# %%
df.head()
# Out:
#    Year  Month  Day approxdate  extended resolution  country  \
# 0  1970      7    2  Not_Known         0  Not_Known       58
# 1  1970      0    0  Not_Known         0  Not_Known      130
# 2  1970      1    0  Not_Known         0  Not_Known      160
# 3  1970      1    0  Not_Known         0  Not_Known       78
# 4  1970      1    0  Not_Known         0  Not_Known      101
#
#               Country  region                       Region  ...   addnotes  \
# 0  Dominican Republic       2  Central America & Caribbean  ...  Not_Known
# 1              Mexico       1                North America  ...  Not_Known
# 2         Philippines       5               Southeast Asia  ...  Not_Known
# 3              Greece       8               Western Europe  ...  Not_Known
# 4               Japan       4                    East Asia  ...  Not_Known
#
#       scite1     scite2     scite3 dbsource  INT_LOG INT_IDEO INT_MISC  \
# 0  Not_Known  Not_Known  Not_Known     PGIS        0        0        0
# ...

# %%
df.loc[:,'Country'].value_counts(dropna = False).sort_index()
# Out:
# Country
# Afghanistan    12731
# Albania           80
# Algeria         2743
# Andorra            1
# Angola           499
#                ...
# Yemen           3347
# Yugoslavia       203
# Zaire             50
# Zambia            62
# Zimbabwe         101
# Name: count, Length: 205, dtype: int64

# %%
plt.subplots(figsize=(15,6))
sns.barplot(x=df['Country'].value_counts()[:15].index,y=df['Country'].value_counts()[:15].values)
plt.title('Top Countries Affected')
plt.xlabel('Countries')
plt.ylabel('Count')
plt.xticks(rotation= 90)
plt.show()

# %%
df.loc[:,'Weapon_type'].value_counts(dropna = False).sort_index()
# Out:
# Weapon_type
# Biological                                                                        35
# Chemical                                                                         321
# Explosives                                                                     92426
# Fake Weapons                                                                      33
# Firearms                                                                       58524
# Incendiary                                                                     11135
# Melee                                                                           3655
# Other                                                                            114
# Radiological                                                                      14
# Sabotage Equipment                                                               141
# Unknown                                                                        15157
# ...

# %%
# Create a countplot for Displaying the count of the weapon types
plt.figure(figsize=(20,10));
sns.countplot(x=df.Weapon_type);

# %%
# Yearly attacks of Terrorism
plt.figure(figsize=(20,5));
plt.xticks(rotation = 90)
plt.title('Attacks by Year')
sns.countplot(x=df.Year);

# %%
# Monthly attack of Terrorism
plt.figure(figsize=(20,5));
plt.title('Attacks by Month')
sns.countplot(x=df.Month);

# %%
# Day basis attack in Terrorism
plt.figure(figsize=(20,5));
plt.title('Attacks by Day')
sns.countplot(x=df.Day);

# %%
# Attacks by each of the country
plt.figure(figsize=(30,5));
plt.rcParams.update({'font.size':8});
plt.xticks(rotation = 90)
plt.title('Attacks by Country')
sns.countplot(x=df.Country);

# %%
# Attacks by the region of each country
plt.figure(figsize=(28,5));
plt.rcParams.update({'font.size':10});
plt.xticks(rotation = 0)
plt.title('Attacks by Region')
sns.countplot(x=df.Region);

# %%
x_year = df['Year'].unique()
y_count_years = df['Year'].value_counts(dropna = False).sort_index()
plt.figure(figsize = (18,10))
sns.barplot(x = x_year,
           y = y_count_years,)
plt.xticks(rotation = 45)
plt.xlabel('Attack Year')
plt.ylabel('Number of Attacks per year')
plt.title('Attacks in Years')
plt.show()

# %%
# Using Crosstab
pd.crosstab(df.Year, df.Region).plot(kind='area',figsize=(15,6))
plt.title('Terrorism by Region in each Year')
plt.ylabel('Number of Attacks')
plt.show()

# %%
print("Country with the most attacks:",df['Country'].value_counts().idxmax())
print("City with the most attacks:",df['city'].value_counts().index[1])
print("Region with the most attacks:",df['Region'].value_counts().idxmax())
print("Year with the most attacks:",df['Year'].value_counts().idxmax())
print("Month with the most attacks:",df['Month'].value_counts().idxmax())
print("Group with the most attacks:",df['Group'].value_counts().index[1])
print("Most Attack Types:",df['AttackType'].value_counts().idxmax())
# Out:
# Country with the most attacks: Iraq
# City with the most attacks: Baghdad
# Region with the most attacks: Middle East & North Africa
# Year with the most attacks: 2014
# Month with the most attacks: 5
# Group with the most attacks: Taliban
# Most Attack Types: Bombing/Explosion

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Assuming df is your DataFrame and 'state' is the column you want to visualize
cities = df['state'].dropna().astype(str)

# Generate a word cloud
wordcloud = WordCloud(width=800, height=400, max_words=200, background_color='white').generate(' '.join(cities))

# Display the word cloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
